# %% [markdown]
# Best optimizer : sgd

# %%
import numpy 
import matplotlib.pyplot as plt
import pandas 
import math

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error,mean_absolute_error
from numpy import array

from keras.layers import Input ,Dense, Dropout, Activation, LSTM
from keras.layers import Convolution2D, MaxPooling2D, Flatten, Reshape,Conv2D
from keras.models import Sequential
from keras.layers.wrappers import TimeDistributed
#from keras.layers.pooling import GlobalAveragePooling1D
#from keras.optimizers import SGD
from keras.utils import np_utils
#from keras.models import Model

import numpy as np
import cv2
from keras.preprocessing.image import img_to_array








from keras import models

from matplotlib import pyplot
from numpy import array
from pandas import DataFrame
import numpy as np

from numpy import array
from keras.models import Sequential
from keras.layers import Dense
from matplotlib import pyplot








from keras import optimizers







import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.optimizers import Adam
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D, GlobalAveragePooling2D
from keras.layers.advanced_activations import LeakyReLU 
from keras.preprocessing.image import ImageDataGenerator
# Out:
# /Users/SindhuPhani/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
num_bins = 16
results_rmse = []
results_mae = []
results_std = []



def train_optimizer_models(opt):
    np.random.seed(3)
    time_steps=19
    # load the dataset
    dataframe = pandas.read_csv('./Trainold.csv')
    dataset = dataframe.values

    scaler = MinMaxScaler(feature_range=(0, 1))


    #print(dataset)

    # we group by day so we can process a video at a time.
    grouped = dataframe.groupby(dataframe.VidName)

    per_vid = []
    for _, group in grouped:
        per_vid.append(group)



    print(len(per_vid))



    trainX=[]
    trainY=[]

    # generate sequences a vid at a time
    for i,vid in enumerate(per_vid):
        histValuesList=[]
        scoreList=[]
        # if we have less than 20 datapoints for a vid we skip over the
        # vid assuming something is missing in the raw data

        total = vid.iloc[:,4:20].values
        vidImPath=vid.iloc[:,0:2].values    

        if len(total) < time_steps :
            continue
        scoreVal=vid["Score"].values[0] + 1    
        max_total_for_vid = scoreVal.tolist()
        #max_total_for_vid = vid["Score"].values[0].tolist()

        for i in range(0,time_steps):
            videoName=vidImPath[i][0]
            imgName=vidImPath[i][1]
            path="./IMAGES/Train/"+videoName+"/"+imgName
            image = cv2.imread(path,0)
            hist = cv2.calcHist([image],[0],None,[num_bins],[0,256])

            hist_arr = hist.flatten()
            #img_arr = img_to_array(image)
            histValuesList.append(hist_arr)
            #scoreList.append(max_total_for_vid)

        trainX.append(histValuesList)
        trainY.append([max_total_for_vid])
        #trainY.append(scoreList)


    print(len(trainX[0]))
    #trainX = np.array([np.array(xi) for xi in trainX])

    trainX=numpy.array(trainX)
    trainY=numpy.array(trainY)

    print(trainX.shape,trainY.shape)





    time_steps=19
    # load the dataset
    dataframe = pandas.read_csv('./Test.csv')
    dataset = dataframe.values

    #print(dataset)

    # we group by day so we can process a video at a time.
    grouped = dataframe.groupby(dataframe.VidName)

    per_vid = []
    for _, group in grouped:
        per_vid.append(group)



    print(len(per_vid))



    testX=[]
    testY=[]

    # generate sequences a vid at a time
    for i,vid in enumerate(per_vid):
        histValuesList=[]
        scoreList=[]
        # if we have less than 20 datapoints for a vid we skip over the
        # vid assuming something is missing in the raw data

        total = vid.iloc[:,4:20].values

        vidImPath=vid.iloc[:,0:2].values


        if len(total)<time_steps :
            continue
        scoreVal=vid["Score"].values[0] + 1    
        max_total_for_vid = scoreVal.tolist()
        #max_total_for_vid = vid["Score"].values[0].tolist()


        for i in range(0,time_steps):
            #histValuesList.append(total[i])
            #print("Vid and Img name")
            #print(req[i][0],req[i][1])
            videoName=vidImPath[i][0]
            imgName=vidImPath[i][1]
            path="./IMAGES/Test/"+videoName+"/"+imgName
            image = cv2.imread(path,0)
            hist = cv2.calcHist([image],[0],None,[num_bins],[0,256])
            hist_arr = hist.flatten()

            histValuesList.append(hist_arr)
            #scoreList.append(max_total_for_vid)


        testX.append(histValuesList)
        testY.append([max_total_for_vid])
        #testY.append(scoreList)


    print(len(testX[0]))
    #trainX = np.array([np.array(xi) for xi in trainX])

    testX=numpy.array(testX)
    testY=numpy.array(testY)

    print(testX.shape,testY.shape)




    trainX=numpy.array(trainX)
    trainX=trainX.reshape(-1,num_bins)
    trainX=trainX.reshape(-1,19,num_bins)
    print(numpy.max(trainX))


    testX=numpy.array(testX)
    testX=testX.reshape(-1,num_bins)
    testX=testX.reshape(-1,19,num_bins)
    print(numpy.max(testX))



    trainX=numpy.array(trainX)
    trainX=trainX.reshape(-1,num_bins)

    trainX = trainX/numpy.max(trainX)

    trainX=trainX.reshape(-1,19,num_bins)
    print(trainX.shape,trainY.shape)




    testX=numpy.array(testX)
    testX=testX.reshape(-1,num_bins)

    testX = testX/numpy.max(testX)

    testX=testX.reshape(-1,19,num_bins)
    print(testX.shape,testY.shape)



    print(trainX.shape,trainY.shape)
    print(testX.shape,testY.shape)
    #print(valX.shape,valY.shape)






    print('Build model...')
    # Build Model
    model = Sequential()  
    model.add(LSTM(100, input_shape=(19, num_bins))) #100
    model.add(Dense(1))
    model.add(Dropout(0.1))
    model.compile(loss='mse', optimizer=opt, metrics=['mse'])

    #model.compile(optimizer='adam', loss = 'mae')

    model.summary()

    history =model.fit(trainX, trainY, nb_epoch=500, batch_size=20, verbose=2,shuffle=True) #500 batch =2     



    # make predictions
    trainPredict = model.predict(trainX)


    trainScore = mean_squared_error(trainY, trainPredict)
    print('Train Score: %.2f MSE' % (trainScore))


    from keras import backend as K

    def root_mean_squared_error(y_true, y_pred):
            return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1)) 

    pred=model.predict(testX)

    print(pred.shape)
    print(testY.shape)



    # calculate root mean squared error
    #trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
    #print('Train Score: %.2f RMSE' % (trainScore))
    testScore = mean_squared_error(testY, pred)
    print('Test Score: %.2f MSE' % (testScore))

    #maeScore = root_mean_squared_error(testY, pred)
    #print('RMSE Score: %.2f MAE' % (maeScore))

    rmse = np.sqrt(((pred - testY) ** 2).mean(axis=0))
    print('RMSE Score: %.2f rmse' % (rmse))


    mae = mean_absolute_error(testY, pred)
    print('MAE Score: %.2f mae' % (mae))

    
    
    list1=[]
    list2=[]
    diff=[]
    
    for i in range(0,len(pred)):

        print(testY[i],pred[i])
        list1.append(testY[i])
        list2.append(pred[i])
        diff.append(abs(testY[i]-pred[i]))
        
    print(numpy.mean(diff))
    stdVals=numpy.std(diff)
        
    results_rmse.append(rmse)
    results_mae.append(mae)
    
    #stdVals = np.std(testY-pred)
    print(stdVals)
    results_std.append(stdVals)
    
    
    
    


adam1 = optimizers.Adam(lr=0.001)
sgd1 = optimizers.SGD(lr=0.005) #0.005 or 6,100 neurons (1.24,1.12 with 0.003 and 0.2 )


for opti in [adam1,sgd1,"rmsprop"]:
    train_optimizer_models(opti)
    
    


newArr1=[]
newArr2=[]
for item in results_rmse:
    newArr1.append(float(item))
    
for item in results_mae:
    newArr2.append(float(item))


rmse_val = tuple(newArr1)
mae_val = tuple(newArr2)   


# data to plot
n_groups = 3


# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8
 
rects1 = plt.bar(index, rmse_val, bar_width,alpha=0.5,color='g',label='RMSE')
 
rects2 = plt.bar(index + bar_width, mae_val, bar_width,alpha=0.3,color='b',label='MAE')
 
    
plt.xlabel('Optimizer')
plt.ylabel('Error Values')
plt.title('Error by Optimizer')
plt.xticks(index + bar_width, ('adam','sgd','rmsprop'))
plt.legend()
 
plt.tight_layout()

axes = plt.gca()
axes.set_ylim([0.70,1.8])

plt.show()
# Out:
# 117
# 19
# (114, 19, 16) (114, 1)
# 55
# 19
# (52, 19, 16) (52, 1)
# 174999.0
# 157653.0
# (114, 19, 16) (114, 1)
# (52, 19, 16) (52, 1)
# (114, 19, 16) (114, 1)
# (52, 19, 16) (52, 1)
# Build model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 100)               46800
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1)                 0
# =================================================================
# Total params: 46,901
# Trainable params: 46,901
# Non-trainable params: 0
# _________________________________________________________________
# /Users/SindhuPhani/anaconda3/lib/python3.6/site-packages/keras/models.py:942: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/500
#  - 1s - loss: 3.2748 - mean_squared_error: 3.2748
# Epoch 2/500
#  - 0s - loss: 2.4943 - mean_squared_error: 2.4943
# Epoch 3/500
#  - 0s - loss: 1.7028 - mean_squared_error: 1.7028
# Epoch 4/500
#  - 0s - loss: 1.3225 - mean_squared_error: 1.3225
# Epoch 5/500
#  - 0s - loss: 1.4041 - mean_squared_error: 1.4041
# Epoch 6/500
#  - 0s - loss: 1.1976 - mean_squared_error: 1.1976
# Epoch 7/500
#  - 0s - loss: 1.5109 - mean_squared_error: 1.5109
# Epoch 8/500
#  - 0s - loss: 1.1573 - mean_squared_error: 1.1573
# Epoch 9/500
#  - 0s - loss: 1.2266 - mean_squared_error: 1.2266
# Epoch 10/500
#  - 0s - loss: 1.2671 - mean_squared_error: 1.2671
# Epoch 11/500
#  - 0s - loss: 1.1874 - mean_squared_error: 1.1874
# Epoch 12/500
#  - 0s - loss: 1.2500 - mean_squared_error: 1.2500
# Epoch 13/500
#  - 0s - loss: 1.1463 - mean_squared_error: 1.1463
# Epoch 14/500
#  - 0s - loss: 1.0293 - mean_squared_error: 1.0293
# Epoch 15/500
#  - 0s - loss: 1.0665 - mean_squared_error: 1.0665
# Epoch 16/500
#  - 0s - loss: 1.2177 - mean_squared_error: 1.2177
# Epoch 17/500
#  - 0s - loss: 1.0970 - mean_squared_error: 1.0970
# Epoch 18/500
#  - 0s - loss: 1.0122 - mean_squared_error: 1.0122
# Epoch 19/500
#  - 0s - loss: 1.3900 - mean_squared_error: 1.3900
# Epoch 20/500
#  - 0s - loss: 1.2957 - mean_squared_error: 1.2957
# Epoch 21/500
#  - 0s - loss: 1.1152 - mean_squared_error: 1.1152
# Epoch 22/500
#  - 0s - loss: 1.2011 - mean_squared_error: 1.2011
# Epoch 23/500
#  - 0s - loss: 0.9756 - mean_squared_error: 0.9756
# Epoch 24/500
#  - 0s - loss: 1.0931 - mean_squared_error: 1.0931
# Epoch 25/500
#  - 0s - loss: 1.1876 - mean_squared_error: 1.1876
# Epoch 26/500
#  - 0s - loss: 0.9996 - mean_squared_error: 0.9996
# Epoch 27/500
#  - 0s - loss: 1.0210 - mean_squared_error: 1.0210
# Epoch 28/500
#  - 0s - loss: 1.3082 - mean_squared_error: 1.3082
# Epoch 29/500
#  - 0s - loss: 1.2543 - mean_squared_error: 1.2543
# Epoch 30/500
#  - 0s - loss: 1.0384 - mean_squared_error: 1.0384
# Epoch 31/500
#  - 0s - loss: 1.0508 - mean_squared_error: 1.0508
# Epoch 32/500
#  - 0s - loss: 0.9288 - mean_squared_error: 0.9288
# Epoch 33/500
#  - 0s - loss: 1.0443 - mean_squared_error: 1.0443
# Epoch 34/500
#  - 0s - loss: 1.1080 - mean_squared_error: 1.1080
# Epoch 35/500
#  - 0s - loss: 1.3551 - mean_squared_error: 1.3551
# Epoch 36/500
#  - 0s - loss: 1.0989 - mean_squared_error: 1.0989
# Epoch 37/500
#  - 0s - loss: 1.2424 - mean_squared_error: 1.2424
# Epoch 38/500
#  - 0s - loss: 1.0276 - mean_squared_error: 1.0276
# Epoch 39/500
#  - 0s - loss: 1.0699 - mean_squared_error: 1.0699
# Epoch 40/500
#  - 0s - loss: 0.8044 - mean_squared_error: 0.8044
# Epoch 41/500
#  - 0s - loss: 0.9359 - mean_squared_error: 0.9359
# Epoch 42/500
#  - 0s - loss: 0.7803 - mean_squared_error: 0.7803
# Epoch 43/500
#  - 0s - loss: 1.0852 - mean_squared_error: 1.0852
# Epoch 44/500
#  - 0s - loss: 0.8303 - mean_squared_error: 0.8303
# Epoch 45/500
#  - 0s - loss: 0.8213 - mean_squared_error: 0.8213
# Epoch 46/500
#  - 0s - loss: 0.9849 - mean_squared_error: 0.9849
# Epoch 47/500
#  - 0s - loss: 1.2030 - mean_squared_error: 1.2030
# Epoch 48/500
#  - 0s - loss: 0.9769 - mean_squared_error: 0.9769
# Epoch 49/500
#  - 0s - loss: 1.0737 - mean_squared_error: 1.0737
# Epoch 50/500
#  - 0s - loss: 1.0230 - mean_squared_error: 1.0230
# Epoch 51/500
#  - 0s - loss: 1.0827 - mean_squared_error: 1.0827
# Epoch 52/500
#  - 0s - loss: 0.9346 - mean_squared_error: 0.9346
# Epoch 53/500
#  - 0s - loss: 0.7355 - mean_squared_error: 0.7355
# Epoch 54/500
# Epoch 468/500
#  - 0s - loss: 0.3060 - mean_squared_error: 0.3060
# Epoch 469/500
#  - 0s - loss: 0.4456 - mean_squared_error: 0.4456
# Epoch 470/500
#  - 0s - loss: 0.6897 - mean_squared_error: 0.6897
# Epoch 471/500
#  - 0s - loss: 0.4728 - mean_squared_error: 0.4728
# Epoch 472/500
#  - 0s - loss: 0.3670 - mean_squared_error: 0.3670
# Epoch 473/500
#  - 0s - loss: 0.2440 - mean_squared_error: 0.2440
# Epoch 474/500
#  - 0s - loss: 0.4573 - mean_squared_error: 0.4573
# Epoch 475/500
#  - 0s - loss: 0.3203 - mean_squared_error: 0.3203
# Epoch 476/500
#  - 0s - loss: 0.2532 - mean_squared_error: 0.2532
# Epoch 477/500
#  - 0s - loss: 0.3271 - mean_squared_error: 0.3271
# Epoch 478/500
#  - 0s - loss: 0.5655 - mean_squared_error: 0.5655
# Epoch 479/500
#  - 0s - loss: 0.4381 - mean_squared_error: 0.4381
# Epoch 480/500
#  - 0s - loss: 0.2375 - mean_squared_error: 0.2375
# Epoch 481/500
#  - 0s - loss: 0.5904 - mean_squared_error: 0.5904
# Epoch 482/500
#  - 0s - loss: 0.1806 - mean_squared_error: 0.1806
# Epoch 483/500
#  - 0s - loss: 0.4090 - mean_squared_error: 0.4090
# Epoch 484/500
#  - 0s - loss: 0.3813 - mean_squared_error: 0.3813
# Epoch 485/500
#  - 0s - loss: 0.3269 - mean_squared_error: 0.3269
# Epoch 486/500
#  - 0s - loss: 0.4659 - mean_squared_error: 0.4659
# Epoch 487/500
#  - 0s - loss: 0.3905 - mean_squared_error: 0.3905
# Epoch 488/500
#  - 0s - loss: 0.5145 - mean_squared_error: 0.5145
# Epoch 489/500
#  - 0s - loss: 0.2962 - mean_squared_error: 0.2962
# Epoch 490/500
#  - 0s - loss: 0.1110 - mean_squared_error: 0.1110
# Epoch 491/500
#  - 0s - loss: 0.1630 - mean_squared_error: 0.1630
# Epoch 492/500
#  - 0s - loss: 0.2567 - mean_squared_error: 0.2567
# Epoch 493/500
#  - 0s - loss: 0.2706 - mean_squared_error: 0.2706
# Epoch 494/500
#  - 0s - loss: 0.3307 - mean_squared_error: 0.3307
# Epoch 495/500
#  - 0s - loss: 0.4153 - mean_squared_error: 0.4153
# Epoch 496/500
#  - 0s - loss: 0.3272 - mean_squared_error: 0.3272
# Epoch 497/500
#  - 0s - loss: 0.2103 - mean_squared_error: 0.2103
# Epoch 498/500
#  - 0s - loss: 0.3158 - mean_squared_error: 0.3158
# Epoch 499/500
#  - 0s - loss: 0.4050 - mean_squared_error: 0.4050
# Epoch 500/500
#  - 0s - loss: 0.5638 - mean_squared_error: 0.5638
# Train Score: 0.07 MSE
# (52, 1)
# (52, 1)
# Test Score: 1.58 MSE
# RMSE Score: 1.26 rmse
# MAE Score: 0.99 mae
# [0] [2.8327532]
# [0] [1.9885182]
# [0] [1.5109632]
# [0] [0.3413732]
# [1] [0.29990625]
# [3] [2.280581]
# [0] [0.10222925]
# [4] [3.7616403]
# [0] [3.807871]
# [0] [1.4809906]
# [3] [2.2626646]
# [4] [1.6671989]
# [1] [1.7709398]
# [2] [1.5119011]
# [1] [0.8093678]
# [2] [2.2113478]
# [1] [2.5260408]
# [2] [2.1744156]
# [1] [2.2238545]
# [0] [0.47702038]
# [0] [0.93316597]
# [0] [1.2076004]
# [2] [1.782807]
# [0] [0.17916393]
# [0] [0.53982806]
# [0] [0.51238304]
# [2] [1.0961119]
# [1] [1.0292227]
# [3] [1.3489114]
# [0] [1.0253018]
# [0] [0.98031926]
# [0] [2.131796]
# [0] [1.6871268]
# [2] [0.7560628]
# [2] [1.8005074]
# [1] [1.5364052]
# [1] [1.5363264]
# [2] [1.1206689]
# [1] [1.9820086]
# [2] [1.2712874]
# [1] [0.0904749]
# [1] [1.114598]
# [4] [2.8094873]
# [1] [0.72500587]
# [1] [2.6973624]
# [2] [2.085906]
# [0] [0.7052235]
# [1] [3.0149207]
# [1] [2.0511005]
# [1] [1.5306618]
# [2] [0.01625782]
# [2] [0.17354192]
# 0.9873914261563466
# 0.77472659372419
# 117
# 19
# (114, 19, 16) (114, 1)
# 55
# 19
# (52, 19, 16) (52, 1)
# 174999.0
# 157653.0
# (114, 19, 16) (114, 1)
# (52, 19, 16) (52, 1)
# (114, 19, 16) (114, 1)
# (52, 19, 16) (52, 1)
# Build model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 100)               46800
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1)                 0
# =================================================================
# Total params: 46,901
# Trainable params: 46,901
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
#  - 1s - loss: 3.2207 - mean_squared_error: 3.2207
# Epoch 2/500
#  - 0s - loss: 2.6435 - mean_squared_error: 2.6435
# Epoch 3/500
#  - 0s - loss: 2.2863 - mean_squared_error: 2.2863
# Epoch 4/500
#  - 0s - loss: 1.8722 - mean_squared_error: 1.8722
# Epoch 5/500
#  - 0s - loss: 1.7193 - mean_squared_error: 1.7193
# Epoch 6/500
#  - 0s - loss: 1.4602 - mean_squared_error: 1.4602
# Epoch 7/500
#  - 0s - loss: 1.6364 - mean_squared_error: 1.6364
# Epoch 8/500
#  - 0s - loss: 1.2655 - mean_squared_error: 1.2655
# Epoch 9/500
#  - 0s - loss: 1.3203 - mean_squared_error: 1.3203
# Epoch 10/500
#  - 0s - loss: 1.3635 - mean_squared_error: 1.3635
# Epoch 11/500
#  - 0s - loss: 1.2775 - mean_squared_error: 1.2775
# Epoch 12/500
#  - 0s - loss: 1.3327 - mean_squared_error: 1.3327
# Epoch 13/500
#  - 0s - loss: 1.2622 - mean_squared_error: 1.2622
# Epoch 14/500
#  - 0s - loss: 1.1279 - mean_squared_error: 1.1279
# Epoch 15/500
#  - 0s - loss: 1.1549 - mean_squared_error: 1.1549
# Epoch 16/500
#  - 0s - loss: 1.2331 - mean_squared_error: 1.2331
# Epoch 17/500
#  - 0s - loss: 1.1763 - mean_squared_error: 1.1763
# Epoch 18/500
#  - 0s - loss: 1.1208 - mean_squared_error: 1.1208
# Epoch 19/500
#  - 0s - loss: 1.4119 - mean_squared_error: 1.4119
# Epoch 20/500
#  - 0s - loss: 1.2397 - mean_squared_error: 1.2397
# Epoch 21/500
#  - 0s - loss: 1.1745 - mean_squared_error: 1.1745
# Epoch 22/500
#  - 0s - loss: 1.2750 - mean_squared_error: 1.2750
# Epoch 23/500
#  - 0s - loss: 1.1163 - mean_squared_error: 1.1163
# Epoch 24/500
#  - 0s - loss: 1.2274 - mean_squared_error: 1.2274
# Epoch 25/500
#  - 0s - loss: 1.3398 - mean_squared_error: 1.3398
# Epoch 26/500
#  - 0s - loss: 1.1622 - mean_squared_error: 1.1622
# Epoch 27/500
#  - 0s - loss: 1.1926 - mean_squared_error: 1.1926
# Epoch 28/500
#  - 0s - loss: 1.4792 - mean_squared_error: 1.4792
# Epoch 29/500
#  - 0s - loss: 1.3674 - mean_squared_error: 1.3674
# Epoch 30/500
#  - 0s - loss: 1.1908 - mean_squared_error: 1.1908
# Epoch 31/500
#  - 0s - loss: 1.2543 - mean_squared_error: 1.2543
# Epoch 32/500
#  - 0s - loss: 1.1513 - mean_squared_error: 1.1513
# Epoch 33/500
#  - 0s - loss: 1.2308 - mean_squared_error: 1.2308
# Epoch 34/500
#  - 0s - loss: 1.2061 - mean_squared_error: 1.2061
# Epoch 35/500
#  - 0s - loss: 1.4920 - mean_squared_error: 1.4920
# Epoch 36/500
#  - 0s - loss: 1.3259 - mean_squared_error: 1.3259
# Epoch 37/500
#  - 0s - loss: 1.4573 - mean_squared_error: 1.4573
# Epoch 38/500
#  - 0s - loss: 1.3136 - mean_squared_error: 1.3136
# Epoch 39/500
#  - 0s - loss: 1.3106 - mean_squared_error: 1.3106
# Epoch 40/500
#  - 0s - loss: 1.0429 - mean_squared_error: 1.0429
# Epoch 41/500
#  - 0s - loss: 1.1793 - mean_squared_error: 1.1793
# Epoch 42/500
#  - 0s - loss: 1.0688 - mean_squared_error: 1.0688
# Epoch 43/500
#  - 0s - loss: 1.3043 - mean_squared_error: 1.3043
# Epoch 44/500
#  - 0s - loss: 1.0651 - mean_squared_error: 1.0651
# Epoch 45/500
#  - 0s - loss: 1.0939 - mean_squared_error: 1.0939
# Epoch 46/500
#  - 0s - loss: 1.2535 - mean_squared_error: 1.2535
# Epoch 47/500
#  - 0s - loss: 1.4435 - mean_squared_error: 1.4435
# Epoch 48/500
#  - 0s - loss: 1.2739 - mean_squared_error: 1.2739
# Epoch 49/500
#  - 0s - loss: 1.3250 - mean_squared_error: 1.3250
# Epoch 50/500
#  - 0s - loss: 1.2862 - mean_squared_error: 1.2862
# Epoch 51/500
#  - 0s - loss: 1.2940 - mean_squared_error: 1.2940
# Epoch 52/500
#  - 0s - loss: 1.2757 - mean_squared_error: 1.2757
# Epoch 53/500
#  - 0s - loss: 1.1059 - mean_squared_error: 1.1059
# Epoch 54/500
#  - 0s - loss: 1.3613 - mean_squared_error: 1.3613
# Epoch 55/500
#  - 0s - loss: 1.1895 - mean_squared_error: 1.1895
# Epoch 56/500
#  - 0s - loss: 1.3562 - mean_squared_error: 1.3562
# Epoch 57/500
#  - 0s - loss: 1.1601 - mean_squared_error: 1.1601
# Epoch 58/500
#  - 0s - loss: 1.2697 - mean_squared_error: 1.2697
# Epoch 59/500
#  - 0s - loss: 1.3555 - mean_squared_error: 1.3555
# Epoch 60/500
#  - 0s - loss: 1.1738 - mean_squared_error: 1.1738
# Epoch 61/500
#  - 0s - loss: 1.1896 - mean_squared_error: 1.1896
# Epoch 62/500
#  - 0s - loss: 1.1311 - mean_squared_error: 1.1311
# Epoch 63/500
#  - 0s - loss: 1.5292 - mean_squared_error: 1.5292
# Epoch 64/500
#  - 0s - loss: 1.4123 - mean_squared_error: 1.4123
# Epoch 65/500
#  - 0s - loss: 1.2114 - mean_squared_error: 1.2114
# Epoch 66/500
#  - 0s - loss: 1.0592 - mean_squared_error: 1.0592
# Epoch 67/500
#  - 0s - loss: 1.3606 - mean_squared_error: 1.3606
# Epoch 68/500
#  - 0s - loss: 1.4002 - mean_squared_error: 1.4002
# Epoch 69/500
#  - 0s - loss: 1.2495 - mean_squared_error: 1.2495
# Epoch 70/500
#  - 0s - loss: 1.2156 - mean_squared_error: 1.2156
# Epoch 71/500
#  - 0s - loss: 1.1351 - mean_squared_error: 1.1351
# Epoch 72/500
#  - 0s - loss: 1.3570 - mean_squared_error: 1.3570
# Epoch 73/500
#  - 0s - loss: 1.2525 - mean_squared_error: 1.2525
# Epoch 74/500
#  - 0s - loss: 1.3230 - mean_squared_error: 1.3230
# Epoch 75/500
#  - 0s - loss: 1.3914 - mean_squared_error: 1.3914
# Epoch 76/500
#  - 0s - loss: 1.2005 - mean_squared_error: 1.2005
# Epoch 77/500
#  - 0s - loss: 1.1911 - mean_squared_error: 1.1911
# Epoch 78/500
#  - 0s - loss: 1.3045 - mean_squared_error: 1.3045
# Epoch 79/500
#  - 0s - loss: 1.1318 - mean_squared_error: 1.1318
# Epoch 80/500
#  - 0s - loss: 1.2436 - mean_squared_error: 1.2436
# Epoch 81/500
#  - 0s - loss: 1.2954 - mean_squared_error: 1.2954
# Epoch 82/500
#  - 0s - loss: 1.2375 - mean_squared_error: 1.2375
# Epoch 83/500
#  - 0s - loss: 1.1468 - mean_squared_error: 1.1468
# Epoch 84/500
#  - 0s - loss: 1.0759 - mean_squared_error: 1.0759
# Epoch 85/500
#  - 0s - loss: 1.2982 - mean_squared_error: 1.2982
# Epoch 86/500
#  - 0s - loss: 1.2754 - mean_squared_error: 1.2754
# Epoch 87/500
#  - 0s - loss: 1.4465 - mean_squared_error: 1.4465
# Epoch 88/500
#  - 0s - loss: 1.4599 - mean_squared_error: 1.4599
# Epoch 89/500
#  - 0s - loss: 1.3742 - mean_squared_error: 1.3742
# Epoch 90/500
#  - 0s - loss: 1.4331 - mean_squared_error: 1.4331
# Epoch 91/500
#  - 0s - loss: 1.1034 - mean_squared_error: 1.1034
# Epoch 92/500
#  - 0s - loss: 1.2888 - mean_squared_error: 1.2888
# Epoch 93/500
#  - 0s - loss: 1.2400 - mean_squared_error: 1.2400
# Epoch 94/500
#  - 0s - loss: 1.2125 - mean_squared_error: 1.2125
# Epoch 95/500
#  - 0s - loss: 1.2229 - mean_squared_error: 1.2229
# Epoch 96/500
#  - 0s - loss: 1.1312 - mean_squared_error: 1.1312
# Epoch 97/500
#  - 0s - loss: 0.9752 - mean_squared_error: 0.9752
# Epoch 98/500
#  - 0s - loss: 1.0844 - mean_squared_error: 1.0844
# Epoch 99/500
#  - 0s - loss: 1.2276 - mean_squared_error: 1.2276
# Epoch 100/500
#  - 0s - loss: 1.3330 - mean_squared_error: 1.3330
# Epoch 101/500
#  - 0s - loss: 1.3195 - mean_squared_error: 1.3195
# Epoch 102/500
#  - 0s - loss: 1.3578 - mean_squared_error: 1.3578
# Epoch 103/500
#  - 0s - loss: 1.2338 - mean_squared_error: 1.2338
# Epoch 104/500
#  - 0s - loss: 1.2858 - mean_squared_error: 1.2858
# Epoch 105/500
#  - 0s - loss: 1.0672 - mean_squared_error: 1.0672
# Epoch 106/500
#  - 0s - loss: 1.1008 - mean_squared_error: 1.1008
# Epoch 107/500
#  - 0s - loss: 1.2908 - mean_squared_error: 1.2908
# Epoch 108/500
#  - 0s - loss: 1.3605 - mean_squared_error: 1.3605
# Epoch 109/500
#  - 0s - loss: 1.3270 - mean_squared_error: 1.3270
# Epoch 110/500
#  - 0s - loss: 1.1687 - mean_squared_error: 1.1687
# Epoch 111/500
#  - 0s - loss: 1.1103 - mean_squared_error: 1.1103
# Epoch 112/500
#  - 0s - loss: 1.3831 - mean_squared_error: 1.3831
# Epoch 113/500
#  - 0s - loss: 1.3315 - mean_squared_error: 1.3315
# Epoch 114/500
#  - 0s - loss: 1.3350 - mean_squared_error: 1.3350
# Epoch 115/500
#  - 0s - loss: 1.2725 - mean_squared_error: 1.2725
# Epoch 116/500
#  - 0s - loss: 1.1742 - mean_squared_error: 1.1742
# Epoch 117/500
#  - 0s - loss: 1.1566 - mean_squared_error: 1.1566
# Epoch 118/500
#  - 0s - loss: 1.1779 - mean_squared_error: 1.1779
# Epoch 119/500
#  - 0s - loss: 1.3334 - mean_squared_error: 1.3334
# Epoch 120/500
#  - 0s - loss: 1.3545 - mean_squared_error: 1.3545
# Epoch 121/500
#  - 0s - loss: 1.3551 - mean_squared_error: 1.3551
# Epoch 122/500
#  - 0s - loss: 1.1533 - mean_squared_error: 1.1533
# Epoch 123/500
#  - 0s - loss: 1.2435 - mean_squared_error: 1.2435
# Epoch 124/500
#  - 0s - loss: 1.4737 - mean_squared_error: 1.4737
# Epoch 125/500
#  - 0s - loss: 1.2715 - mean_squared_error: 1.2715
# Epoch 126/500
#  - 0s - loss: 1.2016 - mean_squared_error: 1.2016
# Epoch 127/500
#  - 0s - loss: 1.2650 - mean_squared_error: 1.2650
# Epoch 128/500
#  - 0s - loss: 1.2655 - mean_squared_error: 1.2655
# Epoch 129/500
#  - 0s - loss: 1.0196 - mean_squared_error: 1.0196
# Epoch 130/500
#  - 0s - loss: 1.1000 - mean_squared_error: 1.1000
# Epoch 131/500
#  - 0s - loss: 1.2490 - mean_squared_error: 1.2490
# Epoch 132/500
#  - 0s - loss: 1.2365 - mean_squared_error: 1.2365
# Epoch 133/500
#  - 0s - loss: 1.1553 - mean_squared_error: 1.1553
# Epoch 134/500
#  - 0s - loss: 1.2845 - mean_squared_error: 1.2845
# Epoch 135/500
#  - 0s - loss: 1.0836 - mean_squared_error: 1.0836
# Epoch 136/500
#  - 0s - loss: 1.3284 - mean_squared_error: 1.3284
# Epoch 137/500
#  - 0s - loss: 1.0988 - mean_squared_error: 1.0988
# Epoch 138/500
#  - 0s - loss: 1.2013 - mean_squared_error: 1.2013
# Epoch 139/500
#  - 0s - loss: 1.2476 - mean_squared_error: 1.2476
# Epoch 140/500
#  - 0s - loss: 1.3626 - mean_squared_error: 1.3626
# Epoch 141/500
#  - 0s - loss: 1.2781 - mean_squared_error: 1.2781
# Epoch 142/500
#  - 0s - loss: 1.3487 - mean_squared_error: 1.3487
# Epoch 143/500
#  - 0s - loss: 1.3246 - mean_squared_error: 1.3246
# Epoch 144/500
#  - 0s - loss: 1.1699 - mean_squared_error: 1.1699
# Epoch 145/500
#  - 0s - loss: 1.1512 - mean_squared_error: 1.1512
# Epoch 146/500
#  - 0s - loss: 1.3803 - mean_squared_error: 1.3803
# Epoch 147/500
#  - 0s - loss: 1.3132 - mean_squared_error: 1.3132
# Epoch 148/500
#  - 0s - loss: 1.2479 - mean_squared_error: 1.2479
# Epoch 149/500
#  - 0s - loss: 1.1304 - mean_squared_error: 1.1304
# Epoch 150/500
#  - 0s - loss: 0.9838 - mean_squared_error: 0.9838
# Epoch 151/500
#  - 0s - loss: 1.0603 - mean_squared_error: 1.0603
# Epoch 152/500
#  - 0s - loss: 1.3608 - mean_squared_error: 1.3608
# Epoch 153/500
#  - 0s - loss: 1.1383 - mean_squared_error: 1.1383
# Epoch 154/500
#  - 0s - loss: 1.4773 - mean_squared_error: 1.4773
# Epoch 155/500
#  - 0s - loss: 1.3109 - mean_squared_error: 1.3109
# Epoch 156/500
#  - 0s - loss: 1.1565 - mean_squared_error: 1.1565
# Epoch 157/500
#  - 0s - loss: 1.0988 - mean_squared_error: 1.0988
# Epoch 158/500
#  - 0s - loss: 1.3712 - mean_squared_error: 1.3712
# Epoch 159/500
#  - 0s - loss: 1.0553 - mean_squared_error: 1.0553
# Epoch 160/500
#  - 0s - loss: 1.1546 - mean_squared_error: 1.1546
# Epoch 161/500
#  - 0s - loss: 1.4788 - mean_squared_error: 1.4788
# Epoch 162/500
#  - 0s - loss: 1.3476 - mean_squared_error: 1.3476
# Epoch 163/500
#  - 0s - loss: 1.2317 - mean_squared_error: 1.2317
# Epoch 164/500
#  - 0s - loss: 1.3975 - mean_squared_error: 1.3975
# Epoch 165/500
#  - 0s - loss: 1.3265 - mean_squared_error: 1.3265
# Epoch 166/500
#  - 0s - loss: 1.3823 - mean_squared_error: 1.3823
# Epoch 167/500
#  - 0s - loss: 1.2385 - mean_squared_error: 1.2385
# Epoch 168/500
#  - 0s - loss: 1.1103 - mean_squared_error: 1.1103
# Epoch 169/500
#  - 0s - loss: 1.2254 - mean_squared_error: 1.2254
# Epoch 170/500
#  - 0s - loss: 1.3569 - mean_squared_error: 1.3569
# Epoch 171/500
#  - 0s - loss: 1.1346 - mean_squared_error: 1.1346
# Epoch 172/500
#  - 0s - loss: 1.2278 - mean_squared_error: 1.2278
# Epoch 173/500
#  - 0s - loss: 1.3399 - mean_squared_error: 1.3399
# Epoch 174/500
#  - 0s - loss: 1.3515 - mean_squared_error: 1.3515
# Epoch 175/500
#  - 0s - loss: 1.4367 - mean_squared_error: 1.4367
# Epoch 176/500
#  - 0s - loss: 1.1479 - mean_squared_error: 1.1479
# Epoch 177/500
#  - 0s - loss: 1.4343 - mean_squared_error: 1.4343
# Epoch 178/500
#  - 0s - loss: 1.2852 - mean_squared_error: 1.2852
# Epoch 179/500
#  - 0s - loss: 1.2912 - mean_squared_error: 1.2912
# Epoch 180/500
#  - 0s - loss: 1.1772 - mean_squared_error: 1.1772
# Epoch 181/500
#  - 0s - loss: 1.1088 - mean_squared_error: 1.1088
# Epoch 182/500
#  - 0s - loss: 1.2359 - mean_squared_error: 1.2359
# Epoch 183/500
#  - 0s - loss: 1.2457 - mean_squared_error: 1.2457
# Epoch 184/500
#  - 0s - loss: 1.1339 - mean_squared_error: 1.1339
# Epoch 185/500
#  - 0s - loss: 1.1102 - mean_squared_error: 1.1102
# Epoch 186/500
#  - 0s - loss: 1.2005 - mean_squared_error: 1.2005
# Epoch 187/500
#  - 0s - loss: 1.3408 - mean_squared_error: 1.3408
# Epoch 188/500
#  - 0s - loss: 1.1210 - mean_squared_error: 1.1210
# Epoch 189/500
#  - 0s - loss: 1.4226 - mean_squared_error: 1.4226
# Epoch 190/500
#  - 0s - loss: 1.2932 - mean_squared_error: 1.2932
# Epoch 191/500
#  - 0s - loss: 1.3432 - mean_squared_error: 1.3432
# Epoch 192/500
#  - 0s - loss: 1.2746 - mean_squared_error: 1.2746
# Epoch 193/500
#  - 0s - loss: 1.1040 - mean_squared_error: 1.1040
# Epoch 194/500
#  - 0s - loss: 1.2621 - mean_squared_error: 1.2621
# Epoch 195/500
#  - 0s - loss: 1.2713 - mean_squared_error: 1.2713
# Epoch 196/500
#  - 0s - loss: 1.1239 - mean_squared_error: 1.1239
# Epoch 197/500
#  - 0s - loss: 1.0394 - mean_squared_error: 1.0394
# Epoch 198/500
#  - 0s - loss: 1.3406 - mean_squared_error: 1.3406
# Epoch 199/500
#  - 0s - loss: 1.2005 - mean_squared_error: 1.2005
# Epoch 200/500
#  - 0s - loss: 1.3962 - mean_squared_error: 1.3962
# Epoch 201/500
#  - 0s - loss: 1.1602 - mean_squared_error: 1.1602
# Epoch 202/500
#  - 0s - loss: 1.1818 - mean_squared_error: 1.1818
# Epoch 203/500
#  - 0s - loss: 1.3020 - mean_squared_error: 1.3020
# Epoch 204/500
#  - 0s - loss: 1.2893 - mean_squared_error: 1.2893
# Epoch 205/500
#  - 0s - loss: 1.2263 - mean_squared_error: 1.2263
# Epoch 206/500
#  - 0s - loss: 1.2712 - mean_squared_error: 1.2712
# Epoch 207/500
# ...
#  - 0s - loss: 0.7297 - mean_squared_error: 0.7297
# Epoch 267/500
# Epoch 380/500
#  - 0s - loss: 0.3867 - mean_squared_error: 0.3867
# Epoch 381/500
#  - 0s - loss: 0.3349 - mean_squared_error: 0.3349
# Epoch 382/500
#  - 0s - loss: 0.4465 - mean_squared_error: 0.4465
# Epoch 383/500
#  - 0s - loss: 0.5218 - mean_squared_error: 0.5218
# Epoch 384/500
#  - 0s - loss: 0.4201 - mean_squared_error: 0.4201
# Epoch 385/500
#  - 0s - loss: 0.1660 - mean_squared_error: 0.1660
# Epoch 386/500
#  - 0s - loss: 0.2763 - mean_squared_error: 0.2763
# Epoch 387/500
#  - 0s - loss: 0.5503 - mean_squared_error: 0.5503
# Epoch 388/500
#  - 0s - loss: 0.4040 - mean_squared_error: 0.4040
# Epoch 389/500
#  - 0s - loss: 0.4633 - mean_squared_error: 0.4633
# Epoch 390/500
#  - 0s - loss: 0.4057 - mean_squared_error: 0.4057
# Epoch 391/500
#  - 0s - loss: 0.2287 - mean_squared_error: 0.2287
# Epoch 392/500
#  - 0s - loss: 0.3536 - mean_squared_error: 0.3536
# Epoch 393/500
#  - 0s - loss: 0.6473 - mean_squared_error: 0.6473
# Epoch 394/500
#  - 0s - loss: 0.5125 - mean_squared_error: 0.5125
# Epoch 395/500
#  - 0s - loss: 0.5025 - mean_squared_error: 0.5025
# Epoch 396/500
#  - 0s - loss: 0.4206 - mean_squared_error: 0.4206
# Epoch 397/500
#  - 0s - loss: 0.5050 - mean_squared_error: 0.5050
# Epoch 398/500
#  - 0s - loss: 0.2746 - mean_squared_error: 0.2746
# Epoch 399/500
#  - 0s - loss: 0.4413 - mean_squared_error: 0.4413
# Epoch 400/500
#  - 0s - loss: 0.3388 - mean_squared_error: 0.3388
# Epoch 401/500
#  - 0s - loss: 0.3611 - mean_squared_error: 0.3611
# Epoch 402/500
#  - 0s - loss: 0.5732 - mean_squared_error: 0.5732
# Epoch 403/500
#  - 0s - loss: 0.5319 - mean_squared_error: 0.5319
# Epoch 404/500
#  - 0s - loss: 0.3418 - mean_squared_error: 0.3418
# Epoch 405/500
#  - 0s - loss: 0.1832 - mean_squared_error: 0.1832
# Epoch 406/500
#  - 0s - loss: 0.5060 - mean_squared_error: 0.5060
# Epoch 407/500
#  - 0s - loss: 0.7043 - mean_squared_error: 0.7043
# Epoch 408/500
#  - 0s - loss: 0.1782 - mean_squared_error: 0.1782
# Epoch 409/500
#  - 0s - loss: 0.2793 - mean_squared_error: 0.2793
# Epoch 410/500
#  - 0s - loss: 0.3080 - mean_squared_error: 0.3080
# Epoch 411/500
#  - 0s - loss: 0.5166 - mean_squared_error: 0.5166
# Epoch 412/500
#  - 0s - loss: 0.3302 - mean_squared_error: 0.3302
# Epoch 413/500
#  - 0s - loss: 0.4381 - mean_squared_error: 0.4381
# Epoch 414/500
#  - 0s - loss: 0.5099 - mean_squared_error: 0.5099
# Epoch 415/500
#  - 0s - loss: 0.3666 - mean_squared_error: 0.3666
# Epoch 416/500
#  - 0s - loss: 0.2632 - mean_squared_error: 0.2632
# Epoch 417/500
#  - 0s - loss: 0.3970 - mean_squared_error: 0.3970
# Epoch 493/500
#  - 0s - loss: 0.3290 - mean_squared_error: 0.3290
# Epoch 494/500
#  - 0s - loss: 0.3350 - mean_squared_error: 0.3350
# Epoch 495/500
#  - 0s - loss: 0.4134 - mean_squared_error: 0.4134
# Epoch 496/500
#  - 0s - loss: 0.3571 - mean_squared_error: 0.3571
# Epoch 497/500
#  - 0s - loss: 0.2397 - mean_squared_error: 0.2397
# Epoch 498/500
#  - 0s - loss: 0.3495 - mean_squared_error: 0.3495
# Epoch 499/500
#  - 0s - loss: 0.4218 - mean_squared_error: 0.4218
# Epoch 500/500
#  - 0s - loss: 0.6347 - mean_squared_error: 0.6347
# Train Score: 0.04 MSE
# (52, 1)
# (52, 1)
# Test Score: 1.85 MSE
# RMSE Score: 1.36 rmse
# MAE Score: 1.08 mae
# [0] [2.6218817]
# [0] [1.3612093]
# [0] [1.9227636]
# [0] [0.74008584]
# [1] [1.1574111]
# [3] [1.990515]
# [0] [0.10096516]
# [4] [1.8720685]
# [0] [3.1571183]
# [0] [1.9606177]
# [3] [2.2134802]
# [4] [1.162869]
# [1] [2.4625828]
# [2] [1.5908641]
# [1] [0.9751701]
# [2] [2.820376]
# [1] [2.9063146]
# [2] [1.8379211]
# [1] [2.9036043]
# [0] [1.8672644]
# [0] [1.3644645]
# [0] [1.1673374]
# [2] [0.64506084]
# [0] [0.06775841]
# [0] [0.9861385]
# [0] [0.5570616]
# [2] [1.3497138]
# [1] [1.1875362]
# [3] [0.8483096]
# [0] [1.2102741]
# [0] [0.70337963]
# [0] [1.5189161]
# [0] [0.9179048]
# [2] [2.0596714]
# [2] [2.4874964]
# [1] [1.5374973]
# [1] [1.7639493]
# [2] [3.233915]
# [1] [1.4395673]
# [2] [1.4480643]
# [1] [0.57982]
# [1] [1.0721384]
# [4] [1.8760375]
# [1] [0.69449186]
# [1] [0.9648141]
# [2] [2.7999039]
# [0] [1.08576]
# [1] [3.8615806]
# [1] [1.0813838]
# [1] [1.1617244]
# [2] [0.10500702]
# [2] [0.11487141]
# 1.0765091454466948
# 0.8340595431999751

# %%
newArr1=[]
newArr2=[]
newArr3=[]
for item in results_rmse:
    newArr1.append(float(item))
    
for item in results_mae:
    newArr2.append(float(item))
    
for item in results_std:
    newArr3.append(float(item))


rmse_val = newArr1
mae_val = newArr2
std_val= newArr3

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd


modelNames= ['adam','sgd','rmsprop']



df = pd.DataFrame(mae_val,index=modelNames,columns=['MAE'])


dfStd = pd.DataFrame(std_val,index=modelNames,columns=['StdDev'])

dfStd
# Out:
#            StdDev
# adam     0.774727
# sgd      0.592679
# rmsprop  0.834060

# %%
df
# Out:
#               MAE
# adam     0.987391
# sgd      0.896965
# rmsprop  1.076509

# %%
p = df.plot(figsize=(10,5),legend=False,kind="bar",rot=10,color="blue",fontsize=10,yerr=dfStd['StdDev'],width=0.3);
p.set_title("MAE (Std) for different optimizers", fontsize=10);
p.set_xlabel("Models", fontsize=10);
p.set_ylabel("Error : MAE (Std)", fontsize=10);

p.set_ylim(0,2.5);
